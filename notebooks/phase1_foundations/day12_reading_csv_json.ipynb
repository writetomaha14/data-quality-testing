# %%
import os
print(os.path.exists(scratch_dir))
print(os.listdir(scratch_dir))

# %%
# %sh pwd

# %%
# %sql
SHOW CATALOGS

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.day12_files

# %%
volume_path = "/Volumes/workspace/default/day12_files"

with open(f"{volume_path}/day12_sample.csv", "w") as f:
    f.write("id,name,department,salary\n1,Alice,IT,55000\n2,Ben,HR,48000\n3,Cara,IT,62000\n")

import os
print(os.path.exists(f"{volume_path}/day12_sample.csv"))

# %%
df = spark.read.option("header", True).csv(f"{volume_path}/day12_sample.csv")
df.display()
df.printSchema()

# %%
df_typed = spark.read.option("header", True).option("inferSchema", True).csv(f"{volume_path}/day12_sample.csv")
df_typed.printSchema()

# %%
with open(f"{volume_path}/day12_sample.json", "w") as f:
    f.write('{"id": 1, "name": "Alice", "department": "IT"}\n{"id": 2, "name": "Ben", "department": "HR"}\n{"id": 3, "name": "Cara", "department": "IT"}\n')

df_json = spark.read.json(f"{volume_path}/day12_sample.json")
df_json.display()
df_json.printSchema()

# %%
# Without multiLine first - watch this behave oddly or fail
with open(f"{volume_path}/day12_sample_array.json", "w") as f:
    f.write('[\n  {"id": 1, "name": "Alice"},\n  {"id": 2, "name": "Ben"}\n]')

df_array_broken = spark.read.json(f"{volume_path}/day12_sample_array.json")
df_array_broken.display()

# %%
# Now with multiLine=True - this is the fix
df_array_fixed = spark.read.option("multiLine", True).json(f"{volume_path}/day12_sample_array.json")
df_array_fixed.display()
